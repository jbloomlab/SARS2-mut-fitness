# %% [markdown]
# # Synonymous mutation spectrum
# Get input variables from [papermill](https://papermill.readthedocs.io/) parameterization (note next cell is tagged as `parameters`):

# %%
input_csv = "results/mutation_counts/aggregated.csv"

# %% [markdown]
# Import Python modules:

# %%
import os

import altair as alt

import numpy

import pandas as pd

import sklearn.decomposition

# %% [markdown]
# Read the mutation counts and assign mutation types:

# %%
mutation_counts = pd.read_csv(input_csv).assign(
    mut_type=lambda x: x["nt_mutation"].map(lambda m: f"{m[0]}to{m[-1]}")
)

mutation_counts
# Out:
#              protein   aa_mutation nt_mutation     codon_change  synonymous  \
# 0             ORF1ab        ORF1ab     C16466T          CCA>CTA       False
# 1                  M             M     T26767C          ATC>ACC       False
# 2       ORF1a;ORF1ab  ORF1a;ORF1ab      C3037T  TTC>TTT;TTC>TTT        True
# 3             ORF1ab        ORF1ab     C19220T          GCT>GTT       False
# 4             ORF1ab        ORF1ab     A17236G          ATA>GTA       False
# ...              ...           ...         ...              ...         ...
# 974785  ORF1a;ORF1ab  ORF1a;ORF1ab      G2900A  GTC>ATC;GTC>ATC       False
# 974786  ORF1a;ORF1ab  ORF1a;ORF1ab      G2867A  GTA>ATA;GTA>ATA       False
# 974787  ORF1a;ORF1ab  ORF1a;ORF1ab      G2782T  GTG>GTT;GTG>GTT        True
# 974788  ORF1a;ORF1ab  ORF1a;ORF1ab      G2525A  GAG>AAG;GAG>AAG       False
# 974789             S             S     T25370C          TTA>CTA        True
#
#         count  reversion_to_ref  reversion_to_founder clade   subset mut_type
# 0          62             False                 False   19A      all     CtoT
# 1          54             False                 False   19A      all     TtoC
# 2          50             False                 False   19A      all     CtoT
# 3          47             False                 False   19A      all     CtoT
# 4          45             False                 False   19A      all     AtoG
# ...       ...               ...                   ...   ...      ...      ...
# 974785      1             False                 False   22C  England     GtoA
# 974786      1             False                 False   22C  England     GtoA
# 974787      1             False                 False   22C  England     GtoT
# 974788      1             False                 False   22C  England     GtoA
# 974789      1             False                 False   22C  England     TtoC
#
# [974790 rows x 11 columns]

# %% [markdown]
# Tally mutation type counts among **only synonymous** mutations for each clade and subset, separating reversions to reference from other mutations:

# %%
mut_type_counts = (
    mutation_counts
    .query("synonymous")
    .groupby(["clade", "subset", "mut_type", "reversion_to_ref"], as_index=False)
    .aggregate({"count": "sum"})
)

mut_types = mut_type_counts["mut_type"].unique().tolist()

# %% [markdown]
# Plot total mutation counts for each clade and subset on a log scale:

# %%
clade_counts = (
    mut_type_counts
    .groupby(["clade", "subset"], as_index=False)
    .aggregate({"count": "sum"})
)

clade_counts_chart = (
    alt.Chart(clade_counts)
    .encode(
        x="clade",
        y=alt.Y("count", title="total mutations"),
        tooltip=["clade", "count"],
        column=alt.Column("subset", title=None),
    )
    .mark_bar()
    .properties(width=alt.Step(12), height=175)
)

clade_counts_chart
# Out:
# alt.Chart(...)

# %% [markdown]
# Plot fraction of mutation counts from reversions to reference.
# Below you can see these fractions are high, probably indicating there is some issue with calling reversions to reference that is still plaguing the data and such reversions should perhaps be ignored:

# %%
reversion_fracs = (
    mut_type_counts
    .groupby(["clade", "subset", "reversion_to_ref"], as_index=False)
    .aggregate({"count": "sum"})
    .assign(frac=lambda x: x["count"] / x.groupby(["clade", "subset"])["count"].transform("sum"))
)

reversion_fracs_chart = (
    alt.Chart(reversion_fracs)
    .encode(
        x="clade",
        y=alt.Y("frac", title="fraction of mutations"),
        color="reversion_to_ref",
        tooltip=["clade", "count", "frac"],
        column=alt.Column("subset", title=None),
    )
    .mark_bar()
    .properties(width=alt.Step(12), height=150)
)

reversion_fracs_chart
# Out:
# alt.Chart(...)

# %%
mutation_counts.groupby(["clade", "reversion_to_ref", "reversion_to_founder"]).aggregate({"count": "sum"})
# Out:
#                                               count
# clade reversion_to_ref reversion_to_founder
# 19A   False            False                  16961
#       True             True                     470
# 20A   False            False                 156036
#                        True                      47
#       True             False                    371
# ...                                             ...
# 22B   True             True                    2183
# 22C   False            False                 191693
#                        True                    1644
#       True             False                   6466
#                        True                    1032
#
# [73 rows x 1 columns]

# %%
(
    mutation_counts
    .query("synonymous")
    .query("subset == 'all'")
   # .query("reversion_to_ref")
    .sort_values("count", ascending=False)
    .query("nt_mutation.str.contains('3037')")
    .head(20)
)
# Out:
#              protein   aa_mutation nt_mutation     codon_change  synonymous  \
# 444189  ORF1a;ORF1ab  ORF1a;ORF1ab      T3037C  TTT>TTC;TTT>TTC        True
# 732326  ORF1a;ORF1ab  ORF1a;ORF1ab      T3037C  TTT>TTC;TTT>TTC        True
# 382770  ORF1a;ORF1ab  ORF1a;ORF1ab      T3037C  TTT>TTC;TTT>TTC        True
# 606162  ORF1a;ORF1ab  ORF1a;ORF1ab      T3037C  TTT>TTC;TTT>TTC        True
# 222414  ORF1a;ORF1ab  ORF1a;ORF1ab      T3037C  TTT>TTC;TTT>TTC        True
# 10589   ORF1a;ORF1ab  ORF1a;ORF1ab      T3037C  TTT>TTC;TTT>TTC        True
# 448391  ORF1a;ORF1ab  ORF1a;ORF1ab      C3037T  TTC>TTT;TTC>TTT        True
# 314168  ORF1a;ORF1ab  ORF1a;ORF1ab      T3037C  TTT>TTC;TTT>TTC        True
# 2       ORF1a;ORF1ab  ORF1a;ORF1ab      C3037T  TTC>TTT;TTC>TTT        True
# 106590  ORF1a;ORF1ab  ORF1a;ORF1ab      T3037C  TTT>TTC;TTT>TTC        True
# 59947   ORF1a;ORF1ab  ORF1a;ORF1ab      T3037C  TTT>TTC;TTT>TTC        True
# 178826  ORF1a;ORF1ab  ORF1a;ORF1ab      T3037C  TTT>TTC;TTT>TTC        True
# 332258  ORF1a;ORF1ab  ORF1a;ORF1ab      T3037C  TTT>TTC;TTT>TTC        True
# 737525  ORF1a;ORF1ab  ORF1a;ORF1ab      C3037T  TTC>TTT;TTC>TTT        True
# 28      ORF1a;ORF1ab  ORF1a;ORF1ab      T3037C  TTT>TTC;TTT>TTC        True
# 860390  ORF1a;ORF1ab  ORF1a;ORF1ab      T3037C  TTT>TTC;TTT>TTC        True
# 621472  ORF1a;ORF1ab  ORF1a;ORF1ab      C3037T  TTC>TTT;TTC>TTT        True
# 360701  ORF1a;ORF1ab  ORF1a;ORF1ab      T3037C  TTT>TTC;TTT>TTC        True
# 144238  ORF1a;ORF1ab  ORF1a;ORF1ab      T3037C  TTT>TTC;TTT>TTC        True
# 62146   ORF1a;ORF1ab  ORF1a;ORF1ab      C3037T  TTC>TTT;TTC>TTT        True
#
#         count  reversion_to_ref  reversion_to_founder clade subset mut_type
# 444189   3459              True                 False   21J    all     TtoC
# 732326    760              True                 False   21M    all     TtoC
# 382770    544              True                 False   21I    all     TtoC
# 606162    214              True                 False   21K    all     TtoC
# 222414     93              True                 False   20I    all     TtoC
# 10589      87              True                 False   20A    all     TtoC
# 448391     76             False                  True   21J    all     CtoT
# 314168     60              True                 False   20J    all     TtoC
# 2          50             False                 False   19A    all     CtoT
# 106590     41              True                 False   20C    all     TtoC
# 59947      37              True                 False   20B    all     TtoC
# 178826     25              True                 False   20G    all     TtoC
# 332258     21              True                 False   21C    all     TtoC
# 737525     17             False                  True   21M    all     CtoT
# 28         17              True                  True   19A    all     TtoC
# 860390     11              True                 False   22B    all     TtoC
# 621472      8             False                  True   21K    all     CtoT
# 360701      8              True                 False   21F    all     TtoC
# 144238      7              True                 False   20E    all     TtoC
# 62146       7             False                  True   20B    all     CtoT

# %%
(
    mutation_counts
    .query("synonymous")
    .query("subset == 'all'")
    .query("not reversion_to_ref")
    .sort_values("count", ascending=False)
    .query("mut_type == 'CtoT'")
    .head(20)
)
# Out:
#              protein   aa_mutation nt_mutation     codon_change  synonymous  \
# 444199             M             M     C26681T          TTC>TTT        True
# 444201         ORF10         ORF10     C29614T          TGC>TGT        True
# 444202        ORF1ab        ORF1ab     C19983T          GTC>GTT        True
# 444203         ORF3a         ORF3a     C25521T          TTC>TTT        True
# 444204             N             N     C29095T          TTC>TTT        True
# 444212        ORF1ab        ORF1ab     C15240T          AAC>AAT        True
# 444213  ORF1a;ORF1ab  ORF1a;ORF1ab      C1912T  TCC>TCT;TCC>TCT        True
# 444216  ORF1a;ORF1ab  ORF1a;ORF1ab      C9430T  ATC>ATT;ATC>ATT        True
# 444217             N             N     C28657T          GAC>GAT        True
# 444221  ORF1a;ORF1ab  ORF1a;ORF1ab       C683T  CTA>TTA;CTA>TTA        True
# 444225        ORF1ab        ORF1ab     C15738T          TTC>TTT        True
# 444229        ORF1ab        ORF1ab     C14724T          TTC>TTT        True
# 444232  ORF1a;ORF1ab  ORF1a;ORF1ab     C10369T  CGC>CGT;CGC>CGT        True
# 444235  ORF1a;ORF1ab  ORF1a;ORF1ab       C823T  GTC>GTT;GTC>GTT        True
# 444240  ORF1a;ORF1ab  ORF1a;ORF1ab       C829T  AAC>AAT;AAC>AAT        True
# 444239             N             N     C28603T          TTC>TTT        True
# 444242        ORF1ab        ORF1ab     C19524T          CTC>CTT        True
# 444244  ORF1a;ORF1ab  ORF1a;ORF1ab      C5512T  AAC>AAT;AAC>AAT        True
# 444246        ORF1ab        ORF1ab     C20178T          GTC>GTT        True
# 444247  ORF1a;ORF1ab  ORF1a;ORF1ab      C1684T  ATC>ATT;ATC>ATT        True
#
#         count  reversion_to_ref  reversion_to_founder clade subset mut_type
# 444199   1679             False                 False   21J    all     CtoT
# 444201   1586             False                 False   21J    all     CtoT
# 444202   1493             False                 False   21J    all     CtoT
# 444203   1479             False                 False   21J    all     CtoT
# 444204   1330             False                 False   21J    all     CtoT
# 444212   1159             False                 False   21J    all     CtoT
# 444213   1156             False                 False   21J    all     CtoT
# 444216   1124             False                 False   21J    all     CtoT
# 444217   1075             False                 False   21J    all     CtoT
# 444221   1000             False                 False   21J    all     CtoT
# 444225    989             False                 False   21J    all     CtoT
# 444229    935             False                 False   21J    all     CtoT
# 444232    925             False                 False   21J    all     CtoT
# 444235    904             False                 False   21J    all     CtoT
# 444240    855             False                 False   21J    all     CtoT
# 444239    855             False                 False   21J    all     CtoT
# 444242    838             False                 False   21J    all     CtoT
# 444244    830             False                 False   21J    all     CtoT
# 444246    823             False                 False   21J    all     CtoT
# 444247    822             False                 False   21J    all     CtoT

# %% [markdown]
# Get PCA of mutation spectrum separately for each clade and stratifying mutations by whether they are reversions to reference:

# %%
mut_type_freqs = (
    mut_type_counts
    .assign(
        total_count=lambda x: x.groupby(["clade", "reversion_to_ref"])["count"].transform("sum"),
        freq=lambda x: x["count"] / x["total_count"],
    )
    .pivot_table(
        index=["clade", "reversion_to_ref", "total_count"],
        values="freq",
        columns="mut_type",
        fill_value=0,
    )
)

pca = sklearn.decomposition.PCA(n_components=2)
pca_coords = pca.fit_transform(mut_type_freqs.values)
assert len(pca_coords) == len(mut_type_freqs)

mut_type_freqs_pca = (
    mut_type_freqs
    .reset_index()
    .assign(
        principal_component_1=pca_coords[:, 0],
        principal_component_2=pca_coords[:, 1],
        log10_total_count=lambda x: numpy.log(x["total_count"]) / numpy.log(10),
    )
)

# %% [markdown]
# Plot mutation spectrum PCA for all clades including both reversions to reference and non reversions to reference:

# %%
mut_type_freqs_chart = (
    alt.Chart(mut_type_freqs_pca)
    .encode(
        x="principal_component_1",
        y="principal_component_2",
        shape="reversion_to_ref",
        color=alt.Color("clade", scale=alt.Scale(scheme="viridis")),
        tooltip=["clade", "reversion_to_ref", "total_count"],
    )
    .mark_point(filled=True, size=50)
)

mut_type_freqs_chart
# Out:
# alt.Chart(...)

# %% [markdown]
# Now do PCA on just non-reversion mutations:

# %%
mut_type_freqs_no_revert = mut_type_freqs.query("reversion_to_ref == False")

pca = sklearn.decomposition.PCA(n_components=2)
pca_coords_no_revert = pca.fit_transform(mut_type_freqs_no_revert.values)
assert len(pca_coords_no_revert) == len(mut_type_freqs_no_revert)

mut_type_freqs_no_revert_pca = (
    mut_type_freqs_no_revert
    .reset_index()
    .assign(
        principal_component_1=pca_coords_no_revert[:, 0],
        principal_component_2=pca_coords_no_revert[:, 1],
        log10_total_count=lambda x: numpy.log(x["total_count"]) / numpy.log(10),
    )
)

# %% [markdown]
# Plot the PCA on just non-reversion mutations:

# %%
total_count_selection = alt.selection_single(
    fields=["log10_total_count"],
    init={"log10_total_count": 4},
    bind=alt.binding_range(
        name="minimum log10 total counts",
        min=int(mut_type_freqs_no_revert_pca["log10_total_count"].min()),
        max=mut_type_freqs_no_revert_pca["log10_total_count"].max(),
    )
)

mut_type_freqs_no_revert_chart = (
    alt.Chart(mut_type_freqs_no_revert_pca)
    .encode(
        x="principal_component_1",
        y="principal_component_2",
        color=alt.Color("clade", scale=alt.Scale(scheme="viridis")),
        tooltip=["clade", "total_count"],
    )
    .mark_point(filled=True, size=50)
    .add_selection(total_count_selection)
    .transform_filter(
        total_count_selection.log10_total_count <= alt.datum.log10_total_count
    )
)

mut_type_freqs_no_revert_chart
# Out:
# alt.Chart(...)
