# %% [markdown]
# # Merge expected and actual counts
#
# First, read the data:

# %%
import pandas as pd


expected = (
    pd.read_csv("../results/expected_mut_counts/expected_mut_counts.csv")
    .rename(columns={"site": "nt_site", "codon": "clade_founder_codon"})
    .assign(
        nt_mutation=lambda x: (
            x["clade_founder_nt"] + x["nt_site"].astype(str) + x["mut_type"].str[-1]
        )
    )
)

actual = pd.read_csv("../results/mutation_counts/aggregated.csv")[
    [
        "clade",
        "subset",
        "nt_site",
        "nt_mutation",
        "codon_change",
        "aa_mutation",
        "count",
    ]
].rename(columns={"count": "actual_count"})

muts_to_exclude = (
    pd.read_csv("../results/expected_vs_actual_mut_counts/mutations_to_exclude.csv")
    .rename(columns={"site": "nt_site", "mutation": "nt_mutation"})
)

# %% [markdown]
# Merge expected and actual, putting counts of any expected that are not observed to zero:

# %%
merged = (
    pd.concat(
        [
            expected.merge(subset_actual, how="left", validate="one_to_many").assign(
                subset=subset,
                actual_count=lambda x: x["actual_count"].fillna(0).astype(int),
            )
            for subset, subset_actual in actual.groupby("subset")
        ],
        ignore_index=True,
    )
)

# %% [markdown]
# Now exclude any mutations that are not from the founder identity codon, which results when there are multiple substitutions per site so that a clade founder identity is different from the reference:

# %%
merged = (
    merged
    .assign(
        start_codon=lambda x: x["codon_change"].map(
                lambda s: pd.NA if pd.isnull(s) else ";".join([c[: 3] for c in s.split(";")])
        ),
        from_founder_codon=lambda x: (
            (x["start_codon"] == x["clade_founder_codon"]) | x["start_codon"].isnull()
        ),
    )
    .query("from_founder_codon")
)

# add back any zero count mutations lost to this process
merged = (
    merged.merge(
        pd.concat([expected.assign(subset=subset) for subset in merged["subset"].unique()]),
        how="outer",
    )
    .assign(actual_count=lambda x: x["actual_count"].fillna(0).astype(int))
)

# %% [markdown]
# Now add the sites to exclude:

# %%
merged = (
    merged
    .merge(
        muts_to_exclude.assign(exclude=True),
        on=["clade", "nt_site", "nt_mutation"],
        how="left",
        validate="many_to_one",
    )
    .assign(exclude=lambda x: x["exclude"].fillna(False))
)

merged
# Out:
#         clade  nt_site clade_founder_nt          gene clade_founder_codon  \
# 0         20A      266                A  ORF1a;ORF1ab             ATG;ATG
# 1         20A      266                A  ORF1a;ORF1ab             ATG;ATG
# 2         20A      266                A  ORF1a;ORF1ab             ATG;ATG
# 3         20A      270                A  ORF1a;ORF1ab             GAG;GAG
# 4         20A      270                A  ORF1a;ORF1ab             GAG;GAG
# ...       ...      ...              ...           ...                 ...
# 3419905   22B    28679                G             N                 GAG
# 3419906   22B    28679                G             N                 GAG
# 3419907   22B      395                C  ORF1a;ORF1ab             CAA;CAA
# 3419908   22B     1625                C  ORF1a;ORF1ab             CTC;CTC
# 3419909   22B    21478                C        ORF1ab                 CTT
#
#         codon_position mut_type  four_fold_degenerate  expected_count  \
# 0                  1;1     AtoC                 False         0.23089
# 1                  1;1     AtoG                 False         1.30730
# 2                  1;1     AtoT                 False         0.41545
# 3                  2;2     AtoC                 False         0.23089
# 4                  2;2     AtoG                 False         1.30730
# ...                ...      ...                   ...             ...
# 3419905              1     GtoA                 False        11.40400
# 3419906              1     GtoT                 False        15.64200
# 3419907            1;1     CtoT                 False        33.66100
# 3419908            1;1     CtoA                 False         2.17220
# 3419909              1     CtoT                 False        33.66100
#
#         nt_mutation   subset codon_change aa_mutation  actual_count  \
# 0             A266C  England          NaN         NaN             0
# 1             A266G  England          NaN         NaN             0
# 2             A266T  England          NaN         NaN             0
# 3             A270C  England          NaN         NaN             0
# 4             A270G  England          NaN         NaN             0
# ...             ...      ...          ...         ...           ...
# 3419905     G28679A      all          NaN         NaN             0
# 3419906     G28679T      all          NaN         NaN             0
# 3419907       C395T      all          NaN         NaN             0
# 3419908      C1625A      all          NaN         NaN             0
# 3419909     C21478T      all          NaN         NaN             0
#
#         start_codon from_founder_codon  exclude
# 0              <NA>               True    False
# 1              <NA>               True    False
# 2              <NA>               True    False
# 3              <NA>               True    False
# 4              <NA>               True    False
# ...             ...                ...      ...
# 3419905         NaN                NaN    False
# 3419906         NaN                NaN    False
# 3419907         NaN                NaN    False
# 3419908         NaN                NaN    False
# 3419909         NaN                NaN    False
#
# [3419910 rows x 17 columns]

# %% [markdown]
# Finally, clean up the data frame and add amino-acid mutations:

# %%
# clean up data frame to just have columns of interest
merged = (
    merged[
        [
            "clade",
            "subset",
            "nt_site",
            "nt_mutation",
            "exclude",
            "expected_count",
            "actual_count",
            "clade_founder_nt",
            "gene",
            "clade_founder_codon",
            "codon_position",
            "four_fold_degenerate",
        ]
    ]
)

merged
# Out:
#         clade   subset  nt_site nt_mutation  exclude  expected_count  \
# 0         20A  England      266       A266C    False         0.23089
# 1         20A  England      266       A266G    False         1.30730
# 2         20A  England      266       A266T    False         0.41545
# 3         20A  England      270       A270C    False         0.23089
# 4         20A  England      270       A270G    False         1.30730
# ...       ...      ...      ...         ...      ...             ...
# 3419905   22B      all    28679     G28679A    False        11.40400
# 3419906   22B      all    28679     G28679T    False        15.64200
# 3419907   22B      all      395       C395T    False        33.66100
# 3419908   22B      all     1625      C1625A    False         2.17220
# 3419909   22B      all    21478     C21478T    False        33.66100
#
#          actual_count clade_founder_nt          gene clade_founder_codon  \
# 0                   0                A  ORF1a;ORF1ab             ATG;ATG
# 1                   0                A  ORF1a;ORF1ab             ATG;ATG
# 2                   0                A  ORF1a;ORF1ab             ATG;ATG
# 3                   0                A  ORF1a;ORF1ab             GAG;GAG
# 4                   0                A  ORF1a;ORF1ab             GAG;GAG
# ...               ...              ...           ...                 ...
# 3419905             0                G             N                 GAG
# 3419906             0                G             N                 GAG
# 3419907             0                C  ORF1a;ORF1ab             CAA;CAA
# 3419908             0                C  ORF1a;ORF1ab             CTC;CTC
# 3419909             0                C        ORF1ab                 CTT
#
#         codon_position  four_fold_degenerate
# 0                  1;1                 False
# 1                  1;1                 False
# 2                  1;1                 False
# 3                  2;2                 False
# 4                  2;2                 False
# ...                ...                   ...
# 3419905              1                 False
# 3419906              1                 False
# 3419907            1;1                 False
# 3419908            1;1                 False
# 3419909              1                 False
#
# [3419910 rows x 12 columns]

# %%
merged[["exclude", "four_fold_degenerate", "actual_count", "expected_count"]].groupby(["exclude", "four_fold_degenerate"]).corr()
# Out:
#                                              actual_count  expected_count
# exclude four_fold_degenerate
# False   False                actual_count        1.000000        0.432518
#                              expected_count      0.432518        1.000000
#         True                 actual_count        1.000000        0.574913
#                              expected_count      0.574913        1.000000
# True    False                actual_count        1.000000        0.198621
#                              expected_count      0.198621        1.000000
#         True                 actual_count        1.000000        0.258195
#                              expected_count      0.258195        1.000000
